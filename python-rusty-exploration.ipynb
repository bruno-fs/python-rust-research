# %% [markdown]
# # Exploration of python packages extended/mixed with rust
#
# Let's analyse the adoption of rust on "popular" on python packages to understand how mainstream packages are using it
# and then use github + pypi data to explore packages using similar approaches.
#
# # Data collection
#
# All data that we will explore here was collected in [another notebook](download_data.ipynb).
# Unfortunately, I didn't add comments on explanations on why/how things were done there, but I'll comment
# about it as we explore it.
#
# # Methodology
#
# ## Identifying a rust package
# We will consider a python + rust package a python package with a `Cargo.toml` in its source code.
# In order to check a source code from a package, data was collected from pypi api for packages
# the source code was uploaded.
#
# ## What was collected from python sources
# - path to `Cargo.toml` and `Cargo.lock` files (ignoring case)
# - build dependencies (using a development version of [pybuild-deps](https://pypi.org/project/pybuild-deps/)
# - content of `Cargo.lock` files
# - errors retrieving/parsing the source code (if any)
#
# # Popular packages
#
# For all intentions and purposes, I'm gonna consider "popular" as a synonym to "most downloaded". That's not necessarily
# true, but we need to start somewhere.
#
# Data was collected from https://pythonwheels.com, which lists the 360 most downloaded packages in the last 30 days (for all
# intentions and purposes, I'm going to consider "popular" as a synonym to "most downloaded")
#
#
# The dataset from pythonwheels.com only contains the package name and the number of downloads.
# Sources were collected for the latest (as of Oct 11 2023) version of the packages listed there.

# %%
import json
from pathlib import Path

import pandas as pd

# %%
wheels_dataset = json.loads(Path("results/cargo-research-pythonwheel.json").read_text())
df_wheels = pd.DataFrame(wheels_dataset)
df_wheels.head()
# Out:
#      pkg_name pkg_version   build_deps  cargo_toml_qty  cargo_lock_qty  \
# 0       boto3     1.28.62           []             0.0             0.0
# 1     urllib3       2.0.6  [hatchling]             0.0             0.0
# 2    botocore     1.31.62           []             0.0             0.0
# 3    requests      2.31.0           []             0.0             0.0
# 4  setuptools      68.2.2           []             0.0             0.0
#
#   cargo_toml cargo_lock cargo_lock_contents  downloads error exc_class
# 0         []         []                  []  750231089   NaN       NaN
# 1         []         []                  []  378371521   NaN       NaN
# 2         []         []                  []  330557585   NaN       NaN
# 3         []         []                  []  323394974   NaN       NaN
# 4         []         []                  []  297651249   NaN       NaN

# %%
print("number of packages not collected/parsed:", df_wheels[~df_wheels.error.isna()].shape[0])
df_wheels[~df_wheels.error.isna()][["pkg_name", "pkg_version", "downloads", "error"]]
# Out:
# number of packages not collected/parsed: 11
#                     pkg_name      pkg_version  downloads  \
# 138             azure-common           1.1.28   31844917
# 143                   msrest            0.7.1   31550696
# 165           azure-identity           1.14.1   28553071
# 174               tb-nightly  2.15.0a20231010   26890751
# 205       redshift-connector          2.0.914   22448408
# 226              tensorboard           2.14.1   20139353
# 266               tensorflow           2.14.0   16119009
# 285                  debugpy            1.8.0   14581674
# 302     tensorflow-estimator           2.14.0   13325343
# 329  tensorboard-data-server            0.7.1   12094937
# 351                     nltk            3.8.1   11019033
#
#                                                  error
# 138  file could not be opened successfully:\n- meth...
# 143  file could not be opened successfully:\n- meth...
# 165  file could not be opened successfully:\n- meth...
# 174  PyPI doesn't have the source code for package ...
# 205  PyPI doesn't have the source code for package ...
# 226  PyPI doesn't have the source code for package ...
# 266  PyPI doesn't have the source code for package ...
# 285  file could not be opened successfully:\n- meth...
# 302  PyPI doesn't have the source code for package ...
# 329  PyPI doesn't have the source code for package ...
# 351  file could not be opened successfully:\n- meth...

# %% [markdown]
# Starting looking at the failures (I like to know the caveats of the process) before jumping to the more interesting stuff:
# out of the 360 most "popular" packages, only 11 coudln't be parsed/downloaded.
#
# The ones that couldn't be parsed are a bug on `pybuild-deps`. It naively assumes sources on pypi are always `tar.gz`. Those seem to be `zip`.
#
# The rest of the errors are for packages that don't have sources available on pypi.

# %% [markdown]
# # rusty popular python packages

# %%
df_wheels[(df_wheels.cargo_toml_qty > 0) | (df_wheels.cargo_lock_qty > 0)]\
[["pkg_name", "pkg_version", "downloads", "build_deps", "cargo_toml_qty", "cargo_lock_qty"]]
# Out:
#           pkg_name pkg_version  downloads  \
# 14    cryptography      41.0.4  186136558
# 98         rpds-py      0.10.4   44442080
# 113         bcrypt       4.0.1   38478981
# 242  pydantic-core      2.10.1   18787799
# 317         orjson       3.9.8   12653856
# 338     tokenizers      0.14.1   11359598
# 355     pre-commit       3.4.0   10899315
#
#                                      build_deps  cargo_toml_qty  \
# 14   [wheel, cffi, setuptools, setuptools-rust]             4.0
# 98                                    [maturin]             1.0
# 113        [wheel, setuptools, setuptools-rust]             1.0
# 242                [maturin, typing-extensions]             1.0
# 317                                   [maturin]            37.0
# 338                                   [maturin]             2.0
# 355                                          []             1.0
#
#      cargo_lock_qty
# 14              1.0
# 98              1.0
# 113             1.0
# 242             1.0
# 317             7.0
# 338             1.0
# 355             0.0

# %% [markdown]
# Excluding pre-commit, all popular rusty popular packages are being built with either `setuptools-rust` or `maturin`.
#
# Interestingly some of thoese packages have multiple manifest (`Cargo.toml`) files. Will better look at this later.

# %% [markdown]
# In the future I'd like to look at a bigger dataset of pypi packages to find out what else is used to build
# python+rust (after a quick google search I found [rust-cpython](https://github.com/dgrunwald/rust-cpython), but it is deprecated).
# For now, lets look at packages that use `setuptools-rust` and/or `maturin`.

# %% [markdown]
# # github projects that depend on setuptools-rust and/or maturin
#
# Using `github-dependents-info` cli, repos depending on `maturin` or `setuptools-rust` were collected. The data from `github-dependents-info` reports the repo name and number of stars.
#
# Packages with at least 10 stars were selected and we searched on pypi (we used the repo name as a search and, if there's nothing on pypi with that exact name, README.md/README.txt was parsed looking for a link to pypi). We could have parsed data directly from github instead of resorting to pypi only - we mostly went with this approach to reuse code used to gather data for wheels dataset. We could get data directly from github in the future.

# %%
github_dataset = json.loads(Path("results/cargo-research-dependants-unique.json").read_text())
df_github = pd.DataFrame(github_dataset)
df_github.shape
# Out:
# (358, 12)

# %%
is_rust_mask = (df_github.cargo_toml_qty > 0) | (df_github.cargo_lock_qty > 0)
df_github[is_rust_mask].shape
# Out:
# (74, 12)

# %%
df_github.error.notna().sum()
# Out:
# 57

# %%
df_github[df_github.error.notna()].error.str.count("PyPI doesn't have the source code for package").sum()
# Out:
# 55

# %%
df_github.is_on_pypi.sum()
# Out:
# 206

# %%
df_github[df_github.is_on_pypi & ~is_rust_mask & df_github.error.isna()]
# Out:
#                               repo  is_on_pypi         pkg_name pkg_version  \
# 0                  certbot/certbot        True          certbot       2.7.1
# 3                  InstaPy/InstaPy        True          instapy      0.6.16
# 4                      ansible/awx        True              awx       0.1.1
# 6                    edgedb/edgedb        True           edgedb       1.7.0
# 7               matrix-org/synapse        True          synapse     2.151.0
# ..                             ...         ...              ...         ...
# 320         christoftorres/Elysium        True          elysium       0.1.0
# 333     chyalexcheng/grainLearning        True    grainlearning       2.0.1
# 346  UnitedTraders/nginxauthdaemon        True  nginxauthdaemon       1.1.0
# 354                  thane98/ignis        True            ignis      0.0.10
# 355              althonos/gb-io.py        True               gb       0.1.4
#
#               build_deps  cargo_toml_qty  cargo_lock_qty cargo_toml  \
# 0                     []             0.0             0.0         []
# 3                     []             0.0             0.0         []
# 4                     []             0.0             0.0         []
# 6           [setuptools]             0.0             0.0         []
# 7    [wheel, setuptools]             0.0             0.0         []
# ..                   ...             ...             ...        ...
# 320        [poetry-core]             0.0             0.0         []
# 333        [poetry-core]             0.0             0.0         []
# 346                   []             0.0             0.0         []
# 354                   []             0.0             0.0         []
# 355        [poetry-core]             0.0             0.0         []
#
#     cargo_lock cargo_lock_contents error exc_class
# 0           []                  []   NaN       NaN
# 3           []                  []   NaN       NaN
# 4           []                  []   NaN       NaN
# 6           []                  []   NaN       NaN
# 7           []                  []   NaN       NaN
# ..         ...                 ...   ...       ...
# 320         []                  []   NaN       NaN
# 333         []                  []   NaN       NaN
# 346         []                  []   NaN       NaN
# 354         []                  []   NaN       NaN
# 355         []                  []   NaN       NaN
#
# [75 rows x 12 columns]

# %% [markdown]
# In total, we were able to parse 358 packages. Rust sources were found in only 74 of those. Why?
#
# First of all only 206 packages were available on PyPI. Out of those, 55 errored when fetching pypi sources, 2 were packaged as zip instead of tar (`pybuild-deps` will need an update to support zip sources), and 75 actually don't have any rust sources. Checking some of the latter, it seems they depend on libraries like cryptography, which in turn depends on setuptools-rust.

# %%
df_ = df_wheels.merge(df_github[["repo", "pkg_name"]], how="left", on="pkg_name")
df_ = pd.concat([df_, df_github])
df_ = df_[~df_.pkg_name.duplicated()].copy()
has_rust_src = (df_.cargo_toml_qty > 0) | (df_.cargo_lock_qty > 0)
df = df_[has_rust_src].copy()
df = df.reset_index()
df = df[['pkg_name', 'pkg_version','repo', 'downloads', 'build_deps', 'cargo_toml_qty',
       'cargo_lock_qty', 'cargo_toml', 'cargo_lock', 'cargo_lock_contents',
       ]].copy()
df.shape
# Out:
# (79, 10)

# %% [markdown]
# For the following analysis only the "rustified" packages were considered, summing a total of 79 when merging wheels + github datasets.

# %% [markdown]
# # Build dependencies

# %%
set(d for deps in df.build_deps for d in deps)
# Out:
# {'cffi',
#  'colorama',
#  'maturin',
#  'numpy',
#  'poetry-core',
#  'protoc-wheel-0',
#  'setuptools',
#  'setuptools-rust',
#  'setuptools-scm',
#  'setuptools-scm-git-archive',
#  'setuptools_rust',
#  'setuptools_scm',
#  'toml',
#  'tomli',
#  'tqdm',
#  'typing-extensions',
#  'wheel'}

# %%
depends_on_maturin = df.build_deps.apply(lambda x: "maturin" in x)
depends_on_setuptools_rust = df.build_deps.apply(lambda x: "setuptools-rust" in x or "setuptools_rust" in x)
print("packages depending on maturin: ", depends_on_maturin.sum())
print("packages depending on setuptools-rust: ", depends_on_setuptools_rust.sum())
print("packages depending on both: ", (depends_on_maturin & depends_on_setuptools_rust).sum())
print("packages depending on neither: ", (~depends_on_maturin & ~depends_on_setuptools_rust).sum())
# Out:
# packages depending on maturin:  48
# packages depending on setuptools-rust:  25
# packages depending on both:  2
# packages depending on neither:  8

# %%
df[depends_on_maturin & depends_on_setuptools_rust]
# Out:
#                     pkg_name pkg_version                                 repo  \
# 50          fast_mail_parser       0.2.5           namecheap/fast_mail_parser
# 78  peace-performance-python       2.0.0  Pure-Peace/peace-performance-python
#
#     downloads                                         build_deps  \
# 50        NaN                  [wheel, maturin, setuptools-rust]
# 78        NaN  [wheel, maturin, toml, setuptools-rust, setupt...
#
#     cargo_toml_qty  cargo_lock_qty  \
# 50             1.0             0.0
# 78             1.0             0.0
#
#                                      cargo_toml cargo_lock cargo_lock_contents
# 50          [fast_mail_parser-0.2.5/Cargo.toml]         []                  []
# 78  [peace-performance-python-2.0.0/Cargo.toml]         []                  []

# %%
df[~depends_on_maturin & ~depends_on_setuptools_rust]
# Out:
#              pkg_name  pkg_version                       repo   downloads  \
# 6          pre-commit        3.4.0                        NaN  10899315.0
# 16             autopy        4.0.0        autopilot-rs/autopy         NaN
# 18    setuptools-rust        1.7.0       PyO3/setuptools-rust         NaN
# 26         tantivy-py  0.11.0-rc.7    quickwit-oss/tantivy-py         NaN
# 54              perde        0.0.2           YushiOMOTE/perde         NaN
# 70  snips-nlu-parsers        0.4.3  snipsco/snips-nlu-parsers         NaN
# 71              flaco        0.6.0         milesgranger/flaco         NaN
# 74    snips-nlu-utils        0.9.1    snipsco/snips-nlu-utils         NaN
#
#                       build_deps  cargo_toml_qty  cargo_lock_qty  \
# 6                             []             1.0             0.0
# 16                            []             1.0             0.0
# 18  [setuptools_scm, setuptools]             6.0             6.0
# 26                            []             1.0             0.0
# 54                            []             1.0             0.0
# 70                            []             1.0             0.0
# 71           [wheel, setuptools]             1.0             1.0
# 74                            []             1.0             0.0
#
#                                            cargo_toml  \
# 6   [pre_commit-3.4.0/pre_commit/resources/empty_t...
# 16                          [autopy-4.0.0/Cargo.toml]
# 18  [setuptools-rust-1.7.0/examples/hello-world/Ca...
# 26                                       [Cargo.toml]
# 54                                       [Cargo.toml]
# 70           [snips_nlu_parsers-0.4.3/ffi/Cargo.toml]
# 71                           [flaco-0.6.0/Cargo.toml]
# 74             [snips_nlu_utils-0.9.1/ffi/Cargo.toml]
#
#                                            cargo_lock  \
# 6                                                  []
# 16                                                 []
# 18  [setuptools-rust-1.7.0/examples/hello-world/Ca...
# 26                                                 []
# 54                                                 []
# 70                                                 []
# 71                           [flaco-0.6.0/Cargo.lock]
# 74                                                 []
#
#                                   cargo_lock_contents
# 6                                                  []
# 16                                                 []
# 18  [{'version': 3, 'package': [{'name': 'autocfg'...
# 26                                                 []
# 54                                                 []
# 70                                                 []
# 71  [{'version': 3, 'package': [{'name': 'ahash', ...
# 74                                                 []

# %% [markdown]
# # Number of manifest files (Cargo.toml)

# %%
df.cargo_toml_qty.describe()
# Out:
# count     79.000000
# mean       5.227848
# std       18.012780
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.500000
# max      146.000000
# Name: cargo_toml_qty, dtype: float64

# %%
df[df.cargo_toml_qty > 1]
# Out:
#            pkg_name pkg_version                      repo    downloads  \
# 0      cryptography      41.0.4         pyca/cryptography  186136558.0
# 4            orjson       3.9.8                ijl/orjson   12653856.0
# 5        tokenizers      0.14.1                       NaN   11359598.0
# 7            polars      0.19.8            pola-rs/polars          NaN
# 10        trustfall       0.1.6      obi1kenobi/trustfall          NaN
# 13          chidori      0.1.26  ThousandBirdsInc/chidori          NaN
# 14            bagua       0.9.2            BaguaSys/bagua          NaN
# 15       pyoxigraph      0.3.19         oxigraph/oxigraph          NaN
# 17         stencila    2.0.0a15         stencila/stencila          NaN
# 18  setuptools-rust       1.7.0      PyO3/setuptools-rust          NaN
# 20        geopolars     0.1.0a4       geopolars/geopolars          NaN
# 22       temporalio       1.3.0     temporalio/sdk-python          NaN
# 32             tapo       0.1.2     mihai-dinculescu/tapo          NaN
# 35          solders      0.18.1       kevinheavey/solders          NaN
# 41           scalib       0.5.6      simple-crypto/SCALib          NaN
# 42       bagua-core       0.4.1       BaguaSys/bagua-core          NaN
# 51          ppca_rs       0.5.1         viodotcom/ppca_rs          NaN
# 55          fastobo      0.12.2        fastobo/fastobo-py          NaN
# 72        chrontext      0.3.11          magbak/chrontext          NaN
# 73          ohmyfpg       0.3.0      se7entyse7en/ohmyfpg          NaN
#
#                                            build_deps  cargo_toml_qty  \
# 0          [wheel, cffi, setuptools, setuptools-rust]             4.0
# 4                                           [maturin]            37.0
# 5                                           [maturin]             2.0
# 7                                           [maturin]            19.0
# 10                             [maturin, poetry-core]             3.0
# 13                                          [maturin]             3.0
# 14  [wheel, colorama, setuptools_scm, tqdm, setupt...             6.0
# 15                                          [maturin]             7.0
# 17                                          [maturin]            31.0
# 18                       [setuptools_scm, setuptools]             6.0
# 20                                          [maturin]             2.0
# 22  [wheel, poetry-core, protoc-wheel-0, setuptool...            11.0
# 32                                          [maturin]             3.0
# 35                                          [maturin]            55.0
# 41  [setuptools-scm-git-archive, wheel, setuptools...             6.0
# 42  [wheel, colorama, setuptools_scm, tqdm, setupt...             5.0
# 51                                          [maturin]             2.0
# 55     [setuptools_rust, setuptools-rust, setuptools]           146.0
# 72                                          [maturin]             3.0
# 73                                          [maturin]             3.0
#
#     cargo_lock_qty                                         cargo_toml  \
# 0              1.0  [cryptography-41.0.4/src/rust/Cargo.toml, cryp...
# 4              7.0  [orjson-3.9.8/Cargo.toml, orjson-3.9.8/include...
# 5              1.0  [tokenizers-0.14.1/tokenizers/Cargo.toml, toke...
# 7              1.0  [polars-0.19.8/crates/polars-io/Cargo.toml, po...
# 10             0.0  [trustfall-0.1.6/local_dependencies/trustfall_...
# 13             2.0  [chidori-0.1.26/local_dependencies/prompt-grap...
# 14             2.0  [bagua-0.9.2/rust/bagua-core/Cargo.toml, bagua...
# 15             1.0  [pyoxigraph-0.3.19/local_dependencies/oxrdf/Ca...
# 17             1.0  [stencila-2.0.0a15/rust/codec/Cargo.toml, sten...
# 18             6.0  [setuptools-rust-1.7.0/examples/hello-world/Ca...
# 20             1.0  [geopolars-0.1.0a4/local_dependencies/geopolar...
# 22             1.0  [temporalio-1.3.0/temporalio/bridge/Cargo.toml...
# 32             1.0  [tapo-0.1.2/tapo/Cargo.toml, tapo-0.1.2/tapo-p...
# 35             1.0  [solders-0.18.1/local_dependencies/solders-ins...
# 41             1.0  [scalib-0.5.6/src/scalib_ext/Cargo.toml, scali...
# 42             1.0  [bagua-core-0.4.1/Cargo.toml, bagua-core-0.4.1...
# 51             1.0  [ppca_rs-0.5.1/local_dependencies/ppca/Cargo.t...
# 55            27.0  [fastobo-0.12.2/Cargo.toml, fastobo-0.12.2/cra...
# 72             1.0  [chrontext-0.3.11/local_dependencies/chrontext...
# 73             0.0  [ohmyfpg-0.3.0/local_dependencies/ohmyfpg_core...
#
#                                            cargo_lock  \
# 0           [cryptography-41.0.4/src/rust/Cargo.lock]
# 4   [orjson-3.9.8/Cargo.lock, orjson-3.9.8/include...
# 5      [tokenizers-0.14.1/bindings/python/Cargo.lock]
# 7                [polars-0.19.8/py-polars/Cargo.lock]
# 10                                                 []
# 13  [chidori-0.1.26/local_dependencies/prompt-grap...
# 14  [bagua-0.9.2/rust/bagua-core/Cargo.lock, bagua...
# 15                     [pyoxigraph-0.3.19/Cargo.lock]
# 17                     [stencila-2.0.0a15/Cargo.lock]
# 18  [setuptools-rust-1.7.0/examples/hello-world/Ca...
# 20                     [geopolars-0.1.0a4/Cargo.lock]
# 22    [temporalio-1.3.0/temporalio/bridge/Cargo.lock]
# 32                            [tapo-0.1.2/Cargo.lock]
# 35                        [solders-0.18.1/Cargo.lock]
# 41           [scalib-0.5.6/src/scalib_ext/Cargo.lock]
# 42                      [bagua-core-0.4.1/Cargo.lock]
# 51                         [ppca_rs-0.5.1/Cargo.lock]
# 55  [fastobo-0.12.2/Cargo.lock, fastobo-0.12.2/cra...
# 72                      [chrontext-0.3.11/Cargo.lock]
# 73                                                 []
#
#                                   cargo_lock_contents
# 0   [{'version': 3, 'package': [{'name': 'Inflecto...
# 4   [{'version': 3, 'package': [{'name': 'ahash', ...
# 5   [{'version': 3, 'package': [{'name': 'aho-cora...
# 7   [{'version': 3, 'package': [{'name': 'addr2lin...
# 10                                                 []
# 13  [{'version': 3, 'package': [{'name': 'ahash', ...
# 14  [{'version': 3, 'package': [{'name': 'addr2lin...
# 15  [{'version': 3, 'package': [{'name': 'adler', ...
# 17  [{'version': 3, 'package': [{'name': 'Inflecto...
# 18  [{'version': 3, 'package': [{'name': 'autocfg'...
# 20  [{'version': 3, 'package': [{'name': 'adler', ...
# 22  [{'version': 3, 'package': [{'name': 'addr2lin...
# 32  [{'version': 3, 'package': [{'name': 'addr2lin...
# 35  [{'version': 3, 'package': [{'name': 'Inflecto...
# 41  [{'version': 3, 'package': [{'name': 'ahash', ...
# 42  [{'version': 3, 'package': [{'name': 'addr2lin...
# 51  [{'version': 3, 'package': [{'name': 'approx',...
# 55  [{'version': 3, 'package': [{'name': 'android_...
# 72  [{'version': 3, 'package': [{'name': 'addr2lin...
# 73                                                 []
